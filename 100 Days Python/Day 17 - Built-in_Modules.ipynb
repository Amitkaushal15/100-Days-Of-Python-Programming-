# %% [markdown]
# ## Built-in Modules

# %% [markdown]
# ### What are modules?

# %% [raw]
# A Python module is a single file containing Python code (with a .py extension) that defines functions, classes, and variables intended for reuse in other programs.

# %% [raw]
# Modules allow you to break down large, complex codebases into smaller, manageable, and logically organized files.

# %% [raw]
# Consider a module to be the same as a code library.
# A file containing a set of functions you want to include in your application.

# %%
Examples of python module

# %%
- Math
- Random
- os
- time

# %% [markdown]
# ### Types of Modules

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# 81d243bd2c585b0f4821__mypyc _tokenize           hmac                random
# IPython             _tracemalloc        html                re
# __future__          _types              http                referencing
# __hello__           _typing             httpcore            reprlib
# __phello__          _uuid               httpx               requests
# _abc                _warnings           idlelib             rfc3339_validator
# _aix_support        _weakref            idna                rfc3986_validator
# _android_support    _weakrefset         imaplib             rfc3987_syntax
# _apple_support      _winapi             importlib           rlcompleter
# _argon2_cffi_bindings _wmi                inspect             rpds
# _ast                _yaml               io                  runpy
# _ast_unparse        _zoneinfo           ipaddress           sched
# ...

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.factorial(5)
# Out:
# 120

# %%
math.pow(2,4)
# Out:
# 16.0

# %%
math.ceil(6.9)
# Out:
# 7

# %%
math.floor(9.5)
# Out:
# 9

# %%
math.sqrt(100)
# Out:
# 10.0

# %% [markdown]
# ### Random module

# %%
import random

# %%
random.randint(1,100)
# Out:
# 85

# %% [markdown]
# a = [1,2,3,45]
# random.shuffle(a)
# print(a)

# %% [markdown]
# ### time module

# %%
import time

# %%
time.time()
# Out:
# 1783696869.305047

# %%
time.ctime()
# Out:
# 'Fri Jul 10 20:52:00 2026'

# %%
print("Hello")
time.sleep(1)
print("world")
# Out:
# Hello
# world

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\akaus'

# %%
os.listdir()
# Out:
# ['-1.14-windows.xml',
#  '.android',
#  '.bash_history',
#  '.cargo',
#  '.codex',
#  '.config',
#  '.copilot',
#  '.docker',
#  '.emulator_console_auth_token',
#  '.gitconfig',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jdks',
#  '.jupyter',
#  '.packettracer',
#  '.python_history',
#  '.rustup',
#  '.skiko',
#  '.templateengine',
#  '.VirtualBox',
#  '.vscode',
#  '.vscode-shared',
#  '.wdc',
#  '3D Objects',
#  'AppData',
#  'Application Data',
#  'Cisco Packet Tracer 8.2.0',
#  'Cisco Packet Tracer 8.2.1',
#  'claw-code',
#  'Contacts',
#  'Cookies',
#  'Day 01 - print_function.ipynb',
#  'Day 02 - Data_Types.ipynb',
#  'Day 03 - comments.ipynb',
#  'Day 04 - variables.ipynb',
#  'Day 05-keywords_and_identifiers.ipynb',
#  'Day 06 - taking_user_input_and_conversion.ipynb',
#  'Day 07 - Type_Conversion.ipynb',
#  'Day 08 - Literals.ipynb',
#  'Day 09 - Operators.ipynb',
#  'Day 10 - If-else_Statements.ipynb',
#  'Day 11 - Indentation.ipynb',
# ...
