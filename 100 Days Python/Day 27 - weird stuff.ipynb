# %% [markdown]
# ## Variable and Memory References

# %% [markdown]
# ### Python's Weird Behaviour

# %% [markdown]
# 1. Getrefcount anomaly
# 2. -5 to 256
# 3. strings

# %%
import sys

# %%
a = 2

# %%
b = a

# %%
c = b

# %%
sys.getrefcount(a)
# Out:
# 3221225472

# %%
a = 69

# %%
b = a

# %%
c = b

# %%
sys.getrefcount(a)
# Out:
# 3221225472

# %%
x = 969

# %%
y = x

# %%
x = y

# %%
sys.getrefcount(x)
# Out:
# 3

# %%
a = "Hello"

# %%
b = a

# %%
c = b

# %%
sys.getrefcount(a)
# Out:
# 4

# %%
a = "Haldia"

# %%
b = "Haldia"

# %%
id(a)
# Out:
# 1732530404016

# %%
id(b)
# Out:
# 1732530404016

# %%
x = "Haldia Institute of Technology"

# %%
y = "Haldia Institute of Technology"

# %%
id(x)
# Out:
# 1732530840528

# %%
id(y)
# Out:
# 1732530841808

# %%
a1 = "Haldia_Instituteof Technology"
