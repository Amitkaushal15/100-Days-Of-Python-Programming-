# %% [markdown]
# ## Comments

# %%
#Comments
# Comments in Python are human-readable notes added to code that the Python interpreter completely ignores during execution. 
# This is comments

# %%
# This is a single-line comment
print("Hello!")  # This is an inline comment
# Out:
# Hello!
