# %% [markdown]
# ## Sets

# %% [markdown]
# 1. Sets do not allow dublicates
# 2. Sets have no indexing/slicing
# 3. Sets don't allow mutable data types
# 4. Set itself is a mutable data type

# %% [markdown]
# 1. What is Sets?
# 2. create
# 3. Access
# 4. Edit
# 5. Add
# 6. Delete
# 7. Operations
# 8. Functions

# %% [markdown]
# ### What is Sets?

# %% [markdown]
# #### In Python, a set is a built-in data type used to store an unordered collection of unique elements. This means duplicate values are automatically removed, and the items have no defined position or index.

# %% [markdown]
# ### Create

# %%
S1 = {}

# %%
S1
# Out:
# {}

# %%
type(S1)
# Out:
# dict

# %%
S1 = set()

# %%
S1
# Out:
# set()

# %%
type(S1)
# Out:
# set

# %%
S1 = {1,2,3,4,5}

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S2 = {"hello", 6, 9.8, True}

# %%
S2
# Out:
# {6, 9.8, True, 'hello'}

# %%
S3 = {1,1,2,2,2,3,3}
S3
# Out:
# {1, 2, 3}

# %%
S4 = {[1,2,3],"Hello"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 S4 = {[1,2,3],"Hello"}
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
S4 = {(1,2,3),"Hello"}

# %%
S4
# Out:
# {(1, 2, 3), 'Hello'}

# %%
S5 = {{1},{2}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 S5 = {{1},{2}}
#
# TypeError: cannot use 'set' as a set element (unhashable type: 'set')

# %% [markdown]
# ### Access

# %%
S2
# Out:
# {6, 9.8, True, 'hello'}

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 S1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
S1[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 S1[-1]
#
# TypeError: 'set' object is not subscriptable

# %%
S1[0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 S1[0:3]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ### Edit

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
s1[0] = 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s1[0] = 100
#
# NameError: name 's1' is not defined

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
id(S1)
# Out:
# 2290872511712

# %%
L1 = list(S1)

# %%
L1
# Out:
# [1, 2, 3, 4, 5]

# %%
L1[0] = 444

# %%
L1
# Out:
# [444, 2, 3, 4, 5]

# %%
S1 = set(L1)

# %%
S1
# Out:
# {2, 3, 4, 5, 444}

# %% [markdown]
# ### Add

# %%
S1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 S1
#
# NameError: name 'S1' is not defined

# %%
S1 = {1,2,3,4,5}

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S1
# Out:
# {1, 2, 3, 4, 5, '98', 98}

# %%
S1.add("Hello")

# %%
S1
# Out:
# {1, 2, 3, 4, 5, '98', 98, 'Hello'}

# %%
id(S1)
# Out:
# 1556100900992

# %%
S1.add(444)

# %%
S1
# Out:
# {1, 2, 3, 4, 444, 5, '98', 98, 'Hello'}

# %%
id(S1)
# Out:
# 1556100900992

# %% [markdown]
# ### Delete

# %% [markdown]
# - del
# - remove
# - pop

# %%
S1.remove(444)

# %%
S1
# Out:
# {1, 2, 3, 4, 5, '98', 98, 'Hello'}

# %%
S1
# Out:
# {1, 2, 3, 4, 5, '98', 98, 'Hello'}

# %%
S2 = {1,2,3,"Hello"}

# %%
del S2

# %%
S2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 S2
#
# NameError: name 'S2' is not defined

# %%
del S1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 del S1[0]
#
# TypeError: 'set' object doesn't support item deletion

# %%
S1.pop()
# Out:
# 3

# %%
S1
# Out:
# {4, 5, '98', 98, 'Hello'}

# %% [markdown]
# ### Operations

# %%
S1 = {1,2,3,4,5}
S2 = {3,5,2,7,8}
S1 + S2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 S1 = {1,2,3,4,5}
#       2 S2 = {3,5,2,7,8}
# ----> 3 S1 + S2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
S1 * 3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 S1 * 3
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
for i in S1:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i in S1
# Out:
# True

# %% [markdown]
# ### Functions

# %%
len(S1)
# Out:
# 5

# %%
min(S1)
# Out:
# 1

# %%
max(S1)
# Out:
# 5

# %%
sorted(S1)
# Out:
# [1, 2, 3, 4, 5]

# %%
sorted(S1, reverse=True)
# Out:
# [5, 4, 3, 2, 1]

# %%
sum(S1)
# Out:
# 15

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S2
# Out:
# {2, 3, 5, 7, 8}

# %%
S1.union(S2)
# Out:
# {1, 2, 3, 4, 5, 7, 8}

# %%
S1.intersection(S2)
# Out:
# {2, 3, 5}

# %%
S1.difference(S2)
# Out:
# {1, 4}

# %%
S2.difference(S1)
# Out:
# {7, 8}

# %%
S1.symmetric_difference(S2)
# Out:
# {1, 4, 7, 8}

# %%
S1.isdisjoint(S2)
# Out:
# False

# %%
S1.issubset(S2)
# Out:
# False

# %%
S1.issuperset(S2)
# Out:
# False
