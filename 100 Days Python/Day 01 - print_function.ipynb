# %%
# Python is case-sensitive
print("Hello World!")
# Out:
# Hello World!

# %%
print(9)
# Out:
# 9

# %%
print(8.5)
# Out:
# 8.5

# %%
a = "Amit"
print(a)
# Out:
# Amit

# %%
print(False)
# Out:
# False

# %%
print(false) #Python is case sensitive. if you type print(false), print(TRUE) instead of print(False),
            # Python assumes youn are looking for a variable, function, or module name FALSE that hasn't been created yet, 
            # Resulting in a NameError.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(false)
#
# NameError: name 'false' is not defined

# %%
print("false")
# Out:
# false

# %%
print("amit", "Navneet", "Adrija", "Suman")
# Out:
# amit Navneet Adrija Suman

# %%
#After typing print function then type "shift+tab" button to see the documentation of print function
print("Amit", 5, 3.5, True)
# Out:
# Amit 5 3.5 True

# %%
print("amit", "Navneet", "Adrija", "Suman", sep="/")
# Out:
# amit/Navneet/Adrija/Suman

# %%
print("amit", "Navneet", "Adrija", "Suman", sep="_")
# Out:
# amit_Navneet_Adrija_Suman

# %%
print("Hello")
print("World!")
# Out:
# Hello
# World!

# %%
print("Hello", end=" ")
print("World!")
# Out:
# Hello World!
